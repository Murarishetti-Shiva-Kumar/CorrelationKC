# %% [markdown]
# ## CorrelationKC
# #Hackathon
# #Team: Gauntlet

# %%
#importing required packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.svm import SVR

# %%
df=pd.read_csv("Data_Set")

# %%
df.head()
# Out:
#   County  Census Tract  Block Group Block Group Concatenation  Population  \
# 0   Cass        600.01            1                  600.01-1         967
# 1   Cass        600.01            2                  600.01-2        1597
# 2   Cass        600.01            3                  600.01-3        1624
# 3   Cass        600.03            1                  600.03-1        1264
# 4   Cass        600.03            2                  600.03-2        2090
#
#    Male  Female  White  Black  Native American  ...  \
# 0   478     489    901     30                0  ...
# 1   779     818   1396     98                5  ...
# 2   813     811   1465     50                4  ...
# 3   589     675   1111     52                6  ...
# 4  1031    1059   1762    165               12  ...
#
#    Current Students 3 Years Or Older In Private Elementary Or High School  \
# 0                                                 84
# 1                                                 55
# ...

# %%
df_required = df[["County",
"Population",
"Male",
"Female",
"White",
"Black",
"Minority",
"Housing Units",
"Aggregate Rent Spent By All Renter Housing Units",
"Rental Units For Which Rent Expenditures Calculated",
"Occupation Of Residents 16 Or Older - Professional And Managerial",
"Occupation Of Residents 16 Or Older - Sales, Office And Administrative Support",
"Occupation Of Residents 16 Or Older - Services",
"Occupation Of Residents 16 Or Older - Farming, Forestry, Or Fishing",
"Occupation Of Residents 16 Or Older - Construction, Extraction And Maintenance",
"Occupation Of Residents 16 Or Older - Production, Transportation And Material Moving",
"Work Classification Of Residents 16 Or Older - Private For-Profit Wage And Salary Workers",
"Work Classification Of Residents 16 Or Older - Private Non-Profit Wage And Salary Workers",
"Work Classification Of Residents 16 Or Older - Government Workers",
"Work Classification Of Residents 16 Or Older - Self-Employed Workers",
"Work Classification Of Residents 16 Or Older - Unpaid Family Workers",
"Means Of Travel To Work Of Employed Persons 16 Or Older - Drove Alone",
"Means Of Travel To Work Of Employed Persons 16 Or Older - Carpool",
"Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit",
"Means Of Travel To Work Of Employed Persons 16 Or Older - Taxicab",
"Means Of Travel To Work Of Employed Persons 16 Or Older - Motorcycle",
"Means Of Travel To Work Of Employed Persons 16 Or Older - Bicycle",
"Means Of Travel To Work Of Employed Persons 16 Or Older - Walked",
"Means Of Travel To Work Of Employed Persons 16 Or Older - Other Means",
"Means Of Travel To Work Of Employed Persons 16 Or Older - Worked At Home",
"Households With Income Less Than $10,000",
"Households With Income $10,000-$14,999",
"Households With Income $15,000-$19,999",
"Households With Income $20,000-$24,999",
"Households With Income $25,000-$29,999",
"Households With Income $30,000-$34,999",
"Households With Income $35,000-$39,999",
"Households With Income $40,000-$44,999",
"Households With Income $45,000-$49,999",
"Households With Income $50,000-$59,999",
"Households With Income $60,000-$74,999",
"Households With Income $75,000-$99,999",
"Households With Income $100,000-$124,999",
"Households With Income $125,000-$149,999",
"Households With Income $150,000-$199,999",
"Households With Income $200,000 Or More",
"White Persons Among Whom Poverty Status Was Determined",
"Black Persons Among Whom Poverty Status Was Determined",
"Persons In Poverty",
"White Persons In Poverty",
"Black Persons In Poverty"]]

# %%
df_required.describe()
# Out:
#         Population         Male       Female        White        Black  \
# count   820.000000   820.000000   820.000000   820.000000   820.000000
# mean   1323.045122   642.401220   680.643902   993.107317   221.536585
# std     747.586926   363.375891   388.692451   767.014360   278.585994
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     795.500000   387.750000   408.750000   480.750000    34.750000
# 50%    1078.000000   532.500000   558.000000   803.000000    99.000000
# 75%    1670.000000   801.250000   869.250000  1372.000000   311.500000
# max    6096.000000  3024.000000  3072.000000  5711.000000  1672.000000
#
#           Minority  Housing Units  \
# count   820.000000     820.000000
# mean    374.997561     591.800000
# std     308.053022     298.744163
# min       0.000000       0.000000
# 25%     141.750000     376.000000
# 50%     264.500000     506.500000
# 75%     539.500000     731.250000
# max    1916.000000    2233.000000
#
# ...

# %%
df_required.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 820 entries, 0 to 819
# Data columns (total 51 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   County                                                                                     820 non-null    object
#  1   Population                                                                                 820 non-null    int64
#  2   Male                                                                                       820 non-null    int64
#  3   Female                                                                                     820 non-null    int64
#  4   White                                                                                      820 non-null    int64
# ...

# %%
df_required.head()
# Out:
#   County  Population  Male  Female  White  Black  Minority  Housing Units  \
# 0   Cass         967   478     489    901     30        77            435
# 1   Cass        1597   779     818   1396     98       244            584
# 2   Cass        1624   813     811   1465     50       220            695
# 3   Cass        1264   589     675   1111     52       246            584
# 4   Cass        2090  1031    1059   1762    165       400            781
#
#    Aggregate Rent Spent By All Renter Housing Units  \
# 0                                           60011.0
# 1                                           53239.0
# 2                                          128954.0
# 3                                          170911.0
# 4                                          120586.0
#
#    Rental Units For Which Rent Expenditures Calculated  ...  \
# 0                                                 33    ...
# 1                                                 53    ...
# ...

# %%
df_train_data=df_required.sample(frac=0.8)

# %%
df_test_data=df_required.sample(frac=0.2)

# %%
pd.DataFrame(df_train_data).to_csv('train_file.csv')

# %%
df_train_data
# Out:
#       County  Population  Male  Female  White  Black  Minority  Housing Units  \
# 8       Cass         997   515     482    757     61       273            452
# 460  Jackson        2089  1028    1061   1751    156       412           1003
# 583  Jackson        3220  1650    1570   3122     19       119           1262
# 775   Platte        2086  1014    1072   1663    257       530            947
# 54      Cass        2301  1076    1225   1783    366       561            997
# ..       ...         ...   ...     ...    ...    ...       ...            ...
# 441  Jackson        1600   792     808   1412     34       243            567
# 603  Jackson        1968   934    1034   1493    313       523            777
# 331  Jackson        1555   764     791    265   1237      1298            728
# 467  Jackson         792   407     385    641     89       193            442
# 238  Jackson        1277   643     634    536    173       980            478
#
# ...

# %%
pd.DataFrame(df_test_data).to_csv('test_file.csv')

# %%
df_test_data
# Out:
#       County  Population  Male  Female  White  Black  Minority  Housing Units  \
# 785   Platte        1720   871     849   1412    135       369            622
# 516  Jackson        1953   908    1045    465   1318      1537           1006
# 606  Jackson        1715   851     864   1576     65       177            615
# 743  Jackson        1372   691     681   1292     44       131            485
# 665  Jackson        1061   532     529   1000      5        84            432
# ..       ...         ...   ...     ...    ...    ...       ...            ...
# 81      Clay        1100   537     563    818    181       330            611
# 124     Clay        1185   566     619   1048     49       189            512
# 734  Jackson         687   399     288    397    213       329            465
# 362  Jackson         954   447     507    545    355       432            486
# 230  Jackson         691   349     342    276    221       474            306
#
# ...

# %%
# Fit regression model
svr_rbf = SVR(kernel='rbf', C=100, gamma=0.1, epsilon=.1)
svr_lin = SVR(kernel='linear', C=100, gamma='auto')
svr_poly = SVR(kernel='poly', C=100, gamma='auto', degree=3, epsilon=.1,
               coef0=1)

# %%
df_county=df_train_data.groupby("County")

# %%
df_county.head()
# Out:
#       County  Population  Male  Female  White  Black  Minority  Housing Units  \
# 8       Cass         997   515     482    757     61       273            452
# 460  Jackson        2089  1028    1061   1751    156       412           1003
# 583  Jackson        3220  1650    1570   3122     19       119           1262
# 775   Platte        2086  1014    1072   1663    257       530            947
# 54      Cass        2301  1076    1225   1783    366       561            997
# 163     Clay        1426   716     710   1250     72       216            657
# 563  Jackson        1468   486     982   1400     32        85           1498
# 596  Jackson         985   543     442    198    625       860            298
# 704  Jackson        1191   664     527    814    224       438            903
# 808   Platte        1845   907     938   1676     68       232            734
# 812   Platte        1276   643     633   1249      0        54            512
# ...

# %%
df_county

# %%
df_county.mean()
# Out:
#           Population        Male      Female        White       Black  \
# County
# Cass     1732.782609  846.608696  886.173913  1593.760870   54.760870
# Clay     1461.767241  715.758621  746.008621  1275.810345   78.500000
# Jackson  1236.565315  597.668919  638.896396   825.306306  297.024775
# Platte   1458.840000  715.660000  743.180000  1264.720000   91.960000
#
#            Minority  Housing Units  \
# County
# Cass     177.717391     695.108696
# Clay     235.387931     625.008621
# Jackson  456.578829     571.594595
# Platte   240.200000     641.540000
#
#          Aggregate Rent Spent By All Renter Housing Units  \
# County
# Cass                                         91929.130435
# Clay                                        114025.112069
# Jackson                                     119530.772523
# Platte                                      163228.280000
#
#          Rental Units For Which Rent Expenditures Calculated  \
# County
# ...

# %%
df_train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 656 entries, 8 to 238
# Data columns (total 51 columns):
#  #   Column                                                                                     Non-Null Count  Dtype
# ---  ------                                                                                     --------------  -----
#  0   County                                                                                     656 non-null    object
#  1   Population                                                                                 656 non-null    int64
#  2   Male                                                                                       656 non-null    int64
#  3   Female                                                                                     656 non-null    int64
#  4   White                                                                                      656 non-null    int64
# ...

# %%
df_train_data.describe()
# Out:
#         Population         Male       Female        White        Black  \
# count   656.000000   656.000000   656.000000   656.000000   656.000000
# mean   1328.125000   645.000000   683.125000   992.346037   225.765244
# std     741.130782   359.811333   386.208131   763.585600   284.490448
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%     799.000000   390.000000   409.750000   460.750000    36.000000
# 50%    1093.000000   537.000000   561.000000   806.500000   100.000000
# 75%    1693.000000   808.500000   884.000000  1381.500000   302.250000
# max    4468.000000  2176.000000  2415.000000  4201.000000  1574.000000
#
#           Minority  Housing Units  \
# count   656.000000     656.000000
# mean    381.419207     595.032012
# std     312.996563     299.528893
# min       0.000000       0.000000
# 25%     145.000000     374.500000
# 50%     272.500000     509.000000
# 75%     550.750000     743.250000
# max    1751.000000    2053.000000
#
# ...

# %%
df_train_data_num=df_train_data.select_dtypes(include=[np.number])

# %%
df_train_data_cat=df_train_data.select_dtypes(include=['object'])

# %%
df_train_data_num.describe().transpose()
# Out:
#                                                     count           mean  \
# Population                                          656.0    1328.125000
# Male                                                656.0     645.000000
# Female                                              656.0     683.125000
# White                                               656.0     992.346037
# Black                                               656.0     225.765244
# Minority                                            656.0     381.419207
# Housing Units                                       656.0     595.032012
# Aggregate Rent Spent By All Renter Housing Units    656.0  119952.332317
# Rental Units For Which Rent Expenditures Calcul...  656.0     188.664634
# Occupation Of Residents 16 Or Older - Professio...  656.0     235.147866
# Occupation Of Residents 16 Or Older - Sales, Of...  656.0     171.397866
# Occupation Of Residents 16 Or Older - Services      656.0     109.221037
# ...

# %%
df_train_data_num_corr=df_train_data_num.corr()

# %% [markdown]
# ## Let's find prediction to "Black Persons In Poverty" Column

# %%
df_train_data_num_corr["Black Persons In Poverty"]
# Out:
# Population                                                                                  -0.084495
# Male                                                                                        -0.110344
# Female                                                                                      -0.059343
# White                                                                                       -0.355192
# Black                                                                                        0.710092
# Minority                                                                                     0.663051
# Housing Units                                                                               -0.007981
# Aggregate Rent Spent By All Renter Housing Units                                             0.093960
# Rental Units For Which Rent Expenditures Calculated                                          0.222109
# ...

# %%
df_train_data_num_cols = []
df_train_data_num_cols.extend(df_train_data_num_corr[(df_train_data_num_corr["Black Persons In Poverty"]>0.3) ].index.values)
df_train_data_num_cols.extend(df_train_data_num_corr[(df_train_data_num_corr["Black Persons In Poverty"]<-0.3) ].index.values)

# %%
df_train_data_num_cols
# Out:
# ['Black',
#  'Minority',
#  'Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit',
#  'Households With Income Less Than $10,000',
#  'Black Persons Among Whom Poverty Status Was Determined',
#  'Persons In Poverty',
#  'Black Persons In Poverty',
#  'White',
#  'White Persons Among Whom Poverty Status Was Determined']

# %%
df_train_data_num_col_filtered=df_train_data_num[df_train_data_num_cols]

# %%
df_train_data_num_col_filtered.head()
# Out:
#      Black  Minority  \
# 8       61       273
# 460    156       412
# 583     19       119
# 775    257       530
# 54     366       561
#
#      Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit  \
# 8                                                    0
# 460                                                  0
# 583                                                  0
# 775                                                 23
# 54                                                   0
#
#      Households With Income Less Than $10,000  \
# 8                                          77
# 460                                       121
# 583                                        44
# 775                                        22
# 54                                          9
#
#      Black Persons Among Whom Poverty Status Was Determined  \
# 8                                                   18
# 460                                                156
# ...

# %%
(df_train_data_num.isnull().sum().sort_values(ascending=False))
# Out:
# Black Persons In Poverty                                                                     0
# Occupation Of Residents 16 Or Older - Farming, Forestry, Or Fishing                          0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit                     0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Carpool                            0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Drove Alone                        0
# Work Classification Of Residents 16 Or Older - Unpaid Family Workers                         0
# Work Classification Of Residents 16 Or Older - Self-Employed Workers                         0
# Work Classification Of Residents 16 Or Older - Government Workers                            0
# Work Classification Of Residents 16 Or Older - Private Non-Profit Wage And Salary Workers    0
# Work Classification Of Residents 16 Or Older - Private For-Profit Wage And Salary Workers    0
# ...

# %%
#As there are no null values found,
# There is no need to find either mean,mode,median and replace them

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df_train_data_cat.head()
# Out:
#       County
# 8       Cass
# 460  Jackson
# 583  Jackson
# 775   Platte
# 54      Cass

# %%
(df_train_data_cat.isnull().sum().sort_values(ascending=False))
# Out:
# County    0
# dtype: int64

# %%
#As there are no null values found,
# There is no need to find either mean,mode,median and replace

# %%
df_train_data_cat1=df_train_data_cat.apply(le.fit_transform)

# %%
df_train_data_cat1.head()
# Out:
#      County
# 8         0
# 460       2
# 583       2
# 775       3
# 54        0

# %%
from sklearn.linear_model import LinearRegression

# %%
Linreg=LinearRegression()

# %%
traindf1=pd.concat([df_train_data_num_col_filtered,df_train_data_cat1],axis=1)

# %%
X1=traindf1.drop(["Black Persons In Poverty"],axis=1)

# %%
y=traindf1["Black Persons In Poverty"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.3)

# %%
df_test_data_num=df_test_data.select_dtypes(include=[np.number])
df_test_data_cat=df_test_data.select_dtypes(include=['object'])

# %%
df_train_data_num_cols.remove('Black Persons In Poverty')

# %%
df_train_data_num_col_filtered=df_test_data_num[df_train_data_num_cols]

# %%
(df_train_data_num_col_filtered.isnull().sum().sort_values(ascending=False))
# Out:
# White Persons Among Whom Poverty Status Was Determined                      0
# White                                                                       0
# Persons In Poverty                                                          0
# Black Persons Among Whom Poverty Status Was Determined                      0
# Households With Income Less Than $10,000                                    0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit    0
# Minority                                                                    0
# Black                                                                       0
# dtype: int64

# %%
(df_test_data_cat.isnull().sum().sort_values(ascending=False))
# Out:
# County    0
# dtype: int64

# %%
df_test_data_cat1=df_test_data_cat.apply(le.fit_transform)

# %%
testdf1=pd.concat([df_train_data_num_col_filtered,df_test_data_cat1],axis=1)

# %%
testdf1.head()
# Out:
#      Black  Minority  \
# 785    135       369
# 516   1318      1537
# 606     65       177
# 743     44       131
# 665      5        84
#
#      Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit  \
# 785                                                  7
# 516                                                 71
# 606                                                 18
# 743                                                  0
# 665                                                  0
#
#      Households With Income Less Than $10,000  \
# 785                                        22
# 516                                        79
# 606                                         2
# 743                                        11
# 665                                        28
#
#      Black Persons Among Whom Poverty Status Was Determined  \
# 785                                                344
# 516                                               1277
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DecTree=DecisionTreeRegressor()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RandFor=RandomForestRegressor(n_estimators=5000)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
GBM=GradientBoostingRegressor(n_estimators=3000)

# %%
LM=Linreg.fit(X_train,y_train)

# %%
LM.score(X_train,y_train)
# Out:
# 0.7777240822404474

# %%
dt_M=DecTree.fit(X_train,y_train)

# %%
dt_M.score(X_train,y_train)
# Out:
# 1.0

# %%
rf_M=RandFor.fit(X_train,y_train)

# %%
rf_M.score(X_train,y_train)
# Out:
# 0.9776811444198237

# %%
gb_M=GBM.fit(X_train,y_train)

# %%
gb_M.score(X_train,y_train)
# Out:
# 0.999999999359107

# %%
from sklearn.metrics import accuracy_score, r2_score

# %%
gb_y_pred = gb_M.predict(X_test)
rf_y_pred = rf_M.predict(X_test)
lm_y_pred = LM.predict(X_test)

# %%
r2_score(y_test,gb_y_pred)
# Out:
# 0.9035632299001993

# %%
r2_score(y_test,rf_y_pred)
# Out:
# 0.9143355086867122

# %%
r2_score(y_test,lm_y_pred)
# Out:
# 0.8115859524911474

# %%
y_eval=gb_M.predict(testdf1)

# %%
pd.DataFrame(y_eval).to_csv('black_poverty.csv')

# %% [markdown]
# ## Let's find prediction to "Households With Income Less Than $10,000" Column

# %%
df_train_data_num_corr["Households With Income Less Than $10,000"]
# Out:
# Population                                                                                   0.106144
# Male                                                                                         0.082965
# Female                                                                                       0.126396
# White                                                                                       -0.100625
# Black                                                                                        0.443880
# Minority                                                                                     0.520875
# Housing Units                                                                                0.279510
# Aggregate Rent Spent By All Renter Housing Units                                             0.355098
# Rental Units For Which Rent Expenditures Calculated                                          0.561087
# ...

# %%
df_train_data_num_cols = []
df_train_data_num_cols.extend(df_train_data_num_corr[(df_train_data_num_corr["Households With Income Less Than $10,000"]>0.3) ].index.values)
df_train_data_num_cols.extend(df_train_data_num_corr[(df_train_data_num_corr["Households With Income Less Than $10,000"]<-0.3) ].index.values)

# %%
df_train_data_num_cols
# Out:
# ['Black',
#  'Minority',
#  'Aggregate Rent Spent By All Renter Housing Units',
#  'Rental Units For Which Rent Expenditures Calculated',
#  'Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit',
#  'Households With Income Less Than $10,000',
#  'Households With Income $10,000-$14,999',
#  'Households With Income $15,000-$19,999',
#  'Persons In Poverty',
#  'White Persons In Poverty',
#  'Black Persons In Poverty']

# %%
df_train_data_num_col_filtered=df_train_data_num[df_train_data_num_cols]

# %%
df_train_data_num_col_filtered.head()
# Out:
#      Black  Minority  Aggregate Rent Spent By All Renter Housing Units  \
# 8       61       273                                           90441.0
# 460    156       412                                          202668.0
# 583     19       119                                           64086.0
# 775    257       530                                          291840.0
# 54     366       561                                          609672.0
#
#      Rental Units For Which Rent Expenditures Calculated  \
# 8                                                  141
# 460                                                394
# 583                                                169
# 775                                                428
# 54                                                 527
#
#      Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit  \
# 8                                                    0
# 460                                                  0
# ...

# %%
(df_train_data_num.isnull().sum().sort_values(ascending=False))
# Out:
# Black Persons In Poverty                                                                     0
# Occupation Of Residents 16 Or Older - Farming, Forestry, Or Fishing                          0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit                     0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Carpool                            0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Drove Alone                        0
# Work Classification Of Residents 16 Or Older - Unpaid Family Workers                         0
# Work Classification Of Residents 16 Or Older - Self-Employed Workers                         0
# Work Classification Of Residents 16 Or Older - Government Workers                            0
# Work Classification Of Residents 16 Or Older - Private Non-Profit Wage And Salary Workers    0
# Work Classification Of Residents 16 Or Older - Private For-Profit Wage And Salary Workers    0
# ...

# %%
#As there are no null values found,
# There is no need to find either mean,mode,median and replace them

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df_train_data_cat.head()
# Out:
#       County
# 8       Cass
# 460  Jackson
# 583  Jackson
# 775   Platte
# 54      Cass

# %%
(df_train_data_cat.isnull().sum().sort_values(ascending=False))
# Out:
# County    0
# dtype: int64

# %%
df_train_data_cat1=df_train_data_cat.apply(le.fit_transform)

# %%
df_train_data_cat1.head()
# Out:
#      County
# 8         0
# 460       2
# 583       2
# 775       3
# 54        0

# %%
from sklearn.linear_model import LinearRegression

# %%
Linreg=LinearRegression()

# %%
traindf1=pd.concat([df_train_data_num_col_filtered,df_train_data_cat1],axis=1)

# %%
X1=traindf1.drop(["Households With Income Less Than $10,000"],axis=1)

# %%
y=traindf1["Households With Income Less Than $10,000"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.3)

# %%
df_test_data_num=df_test_data.select_dtypes(include=[np.number])
df_test_data_cat=df_test_data.select_dtypes(include=['object'])

# %%
df_train_data_num_cols.remove('Households With Income Less Than $10,000')

# %%
df_train_data_num_col_filtered=df_test_data_num[df_train_data_num_cols]

# %%
(df_train_data_num_col_filtered.isnull().sum().sort_values(ascending=False))
# Out:
# Black Persons In Poverty                                                    0
# White Persons In Poverty                                                    0
# Persons In Poverty                                                          0
# Households With Income $15,000-$19,999                                      0
# Households With Income $10,000-$14,999                                      0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit    0
# Rental Units For Which Rent Expenditures Calculated                         0
# Aggregate Rent Spent By All Renter Housing Units                            0
# Minority                                                                    0
# Black                                                                       0
# dtype: int64

# %%
(df_test_data_cat.isnull().sum().sort_values(ascending=False))
# Out:
# County    0
# dtype: int64

# %%
df_test_data_cat1=df_test_data_cat.apply(le.fit_transform)

# %%
testdf1=pd.concat([df_train_data_num_col_filtered,df_test_data_cat1],axis=1)

# %%
testdf1.head()
# Out:
#      Black  Minority  Aggregate Rent Spent By All Renter Housing Units  \
# 785    135       369                                          145606.0
# 516   1318      1537                                          281305.0
# 606     65       177                                           72506.0
# 743     44       131                                           39080.0
# 665      5        84                                           47725.0
#
#      Rental Units For Which Rent Expenditures Calculated  \
# 785                                                151
# 516                                                531
# 606                                                 70
# 743                                                 23
# 665                                                118
#
#      Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit  \
# 785                                                  7
# 516                                                 71
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DecTree=DecisionTreeRegressor()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RandFor=RandomForestRegressor(n_estimators=5000)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
GBM=GradientBoostingRegressor(n_estimators=3000)

# %%
LM=Linreg.fit(X_train,y_train)

# %%
LM.score(X_train,y_train)
# Out:
# 0.6692423060723749

# %%
dt_M=DecTree.fit(X_train,y_train)

# %%
dt_M.score(X_train,y_train)
# Out:
# 1.0

# %%
rf_M=RandFor.fit(X_train,y_train)

# %%
rf_M.score(X_train,y_train)
# Out:
# 0.9292033620708507

# %%
gb_M=GBM.fit(X_train,y_train)

# %%
gb_M.score(X_train,y_train)
# Out:
# 0.9999999987646201

# %%
from sklearn.metrics import accuracy_score, r2_score

# %%
gb_y_pred = gb_M.predict(X_test)
rf_y_pred = rf_M.predict(X_test)
lm_y_pred = LM.predict(X_test)

# %%
r2_score(y_test,gb_y_pred)
# Out:
# 0.5495839233986555

# %%
r2_score(y_test,rf_y_pred)
# Out:
# 0.5218961278102124

# %%
r2_score(y_test,lm_y_pred)
# Out:
# 0.5852829169881493

# %%
y_eval=gb_M.predict(testdf1)

# %%
pd.DataFrame(y_eval).to_csv('income.csv')

# %% [markdown]
# ## Let's find prediction to "Minority" Column

# %%
df_train_data_num_corr["Minority"]
# Out:
# Population                                                                                   0.179081
# Male                                                                                         0.149580
# Female                                                                                       0.204299
# White                                                                                       -0.217318
# Black                                                                                        0.893905
# Minority                                                                                     1.000000
# Housing Units                                                                                0.234678
# Aggregate Rent Spent By All Renter Housing Units                                             0.251842
# Rental Units For Which Rent Expenditures Calculated                                          0.400967
# ...

# %%
df_train_data_num_cols = []
df_train_data_num_cols.extend(df_train_data_num_corr[(df_train_data_num_corr["Minority"]>0.3) ].index.values)
df_train_data_num_cols.extend(df_train_data_num_corr[(df_train_data_num_corr["Minority"]<-0.3) ].index.values)

# %%
df_train_data_num_cols
# Out:
# ['Black',
#  'Minority',
#  'Rental Units For Which Rent Expenditures Calculated',
#  'Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit',
#  'Households With Income Less Than $10,000',
#  'Households With Income $10,000-$14,999',
#  'Households With Income $15,000-$19,999',
#  'Households With Income $20,000-$24,999',
#  'Households With Income $25,000-$29,999',
#  'Black Persons Among Whom Poverty Status Was Determined',
#  'Persons In Poverty',
#  'Black Persons In Poverty']

# %%
df_train_data_num_col_filtered=df_train_data_num[df_train_data_num_cols]

# %%
df_train_data_num_col_filtered.head()
# Out:
#      Black  Minority  Rental Units For Which Rent Expenditures Calculated  \
# 8       61       273                                                141
# 460    156       412                                                394
# 583     19       119                                                169
# 775    257       530                                                428
# 54     366       561                                                527
#
#      Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit  \
# 8                                                    0
# 460                                                  0
# 583                                                  0
# 775                                                 23
# 54                                                   0
#
#      Households With Income Less Than $10,000  \
# 8                                          77
# 460                                       121
# ...

# %%
(df_train_data_num.isnull().sum().sort_values(ascending=False))
# Out:
# Black Persons In Poverty                                                                     0
# Occupation Of Residents 16 Or Older - Farming, Forestry, Or Fishing                          0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit                     0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Carpool                            0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Drove Alone                        0
# Work Classification Of Residents 16 Or Older - Unpaid Family Workers                         0
# Work Classification Of Residents 16 Or Older - Self-Employed Workers                         0
# Work Classification Of Residents 16 Or Older - Government Workers                            0
# Work Classification Of Residents 16 Or Older - Private Non-Profit Wage And Salary Workers    0
# Work Classification Of Residents 16 Or Older - Private For-Profit Wage And Salary Workers    0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
df_train_data_cat.head()
# Out:
#       County
# 8       Cass
# 460  Jackson
# 583  Jackson
# 775   Platte
# 54      Cass

# %%
(df_train_data_cat.isnull().sum().sort_values(ascending=False))
# Out:
# County    0
# dtype: int64

# %%
df_train_data_cat1=df_train_data_cat.apply(le.fit_transform)

# %%
df_train_data_cat1.head()
# Out:
#      County
# 8         0
# 460       2
# 583       2
# 775       3
# 54        0

# %%
from sklearn.linear_model import LinearRegression

# %%
Linreg=LinearRegression()

# %%
traindf1=pd.concat([df_train_data_num_col_filtered,df_train_data_cat1],axis=1)

# %%
X1=traindf1.drop(["Minority"],axis=1)

# %%
y=traindf1["Minority"]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X1, y, test_size=0.3)

# %%
df_test_data_num=df_test_data.select_dtypes(include=[np.number])
df_test_data_cat=df_test_data.select_dtypes(include=['object'])

# %%
df_train_data_num_cols.remove('Minority')

# %%
df_train_data_num_col_filtered=df_test_data_num[df_train_data_num_cols]

# %%
(df_train_data_num_col_filtered.isnull().sum().sort_values(ascending=False))
# Out:
# Black Persons In Poverty                                                    0
# Persons In Poverty                                                          0
# Black Persons Among Whom Poverty Status Was Determined                      0
# Households With Income $25,000-$29,999                                      0
# Households With Income $20,000-$24,999                                      0
# Households With Income $15,000-$19,999                                      0
# Households With Income $10,000-$14,999                                      0
# Households With Income Less Than $10,000                                    0
# Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit    0
# Rental Units For Which Rent Expenditures Calculated                         0
# Black                                                                       0
# dtype: int64

# %%
(df_test_data_cat.isnull().sum().sort_values(ascending=False))
# Out:
# County    0
# dtype: int64

# %%
df_test_data_cat1=df_test_data_cat.apply(le.fit_transform)

# %%
testdf1=pd.concat([df_train_data_num_col_filtered,df_test_data_cat1],axis=1)

# %%
testdf1.head()
# Out:
#      Black  Rental Units For Which Rent Expenditures Calculated  \
# 785    135                                                151
# 516   1318                                                531
# 606     65                                                 70
# 743     44                                                 23
# 665      5                                                118
#
#      Means Of Travel To Work Of Employed Persons 16 Or Older - Public Transit  \
# 785                                                  7
# 516                                                 71
# 606                                                 18
# 743                                                  0
# 665                                                  0
#
#      Households With Income Less Than $10,000  \
# 785                                        22
# 516                                        79
# 606                                         2
# ...

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
DecTree=DecisionTreeRegressor()

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
RandFor=RandomForestRegressor(n_estimators=5000)

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
GBM=GradientBoostingRegressor(n_estimators=3000)

# %%
LM=Linreg.fit(X_train,y_train)

# %%
LM.score(X_train,y_train)
# Out:
# 0.9036207148369206

# %%
dt_M=DecTree.fit(X_train,y_train)

# %%
dt_M.score(X_train,y_train)
# Out:
# 1.0

# %%
rf_M=RandFor.fit(X_train,y_train)

# %%
rf_M.score(X_train,y_train)
# Out:
# 0.9856225286913493

# %%
gb_M=GBM.fit(X_train,y_train)

# %%
gb_M.score(X_train,y_train)
# Out:
# 0.9999999998720369

# %%
from sklearn.metrics import accuracy_score, r2_score

# %%
r2_score(y_test,gb_y_pred)
# Out:
# -1.140828070272267

# %%
r2_score(y_test,rf_y_pred)
# Out:
# -1.1188252585791179

# %%
r2_score(y_test,lm_y_pred)
# Out:
# -1.110861957876046

# %%
y_eval=gb_M.predict(testdf1)

# %%
pd.DataFrame(y_eval).to_csv('Minority.csv')
